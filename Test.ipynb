# %%
from subchain import Subchain

test = Subchain(4, 16)
test.start()
# Out:
# the size of train: 65328, dev:872, test:2021
# train.fields: {'text': <torchtext.data.field.Field object at 0x000002AD5C78C160>, 'label': <torchtext.data.field.Field object at 0x000002AD5C781D60>} torch.Size([14795, 50])
# epoch=0,测试准确率=0.49609375
# epoch=1,测试准确率=0.49609375
# epoch=2,测试准确率=0.49609375
# epoch=3,测试准确率=0.49609375
# epoch=4,测试准确率=0.49609375
# epoch=5,测试准确率=0.49609375
# epoch=6,测试准确率=0.49609375
# epoch=7,测试准确率=0.49609375
# epoch=8,测试准确率=0.49609375
# epoch=9,测试准确率=0.5
# epoch=10,测试准确率=0.5
# epoch=11,测试准确率=0.513671875
# epoch=12,测试准确率=0.533203125
# epoch=13,测试准确率=0.5625
# epoch=14,测试准确率=0.58984375
# epoch=15,测试准确率=0.6015625
# epoch=16,测试准确率=0.615234375
# epoch=17,测试准确率=0.634765625
# epoch=18,测试准确率=0.6328125
# epoch=19,测试准确率=0.62890625
# epoch=20,测试准确率=0.62109375
# epoch=21,测试准确率=0.625
# epoch=22,测试准确率=0.650390625
# epoch=23,测试准确率=0.677734375
# epoch=24,测试准确率=0.703125
# epoch=25,测试准确率=0.744140625
# epoch=26,测试准确率=0.74609375
# epoch=27,测试准确率=0.759765625
# ...

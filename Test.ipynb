# %%
from subchain import Subchain

test = Subchain(1, 32)
test.start()
# Out:
# the size of train: 65328, dev:872, test:2021
# train.fields: {'text': <torchtext.data.field.Field object at 0x000002DE9C17CA00>, 'label': <torchtext.data.field.Field object at 0x000002DE9C17C160>} torch.Size([14795, 50])
# epoch=0,测试准确率=0.50390625
# epoch=1,测试准确率=0.5703125
# epoch=2,测试准确率=0.56640625
# epoch=3,测试准确率=0.51171875
# epoch=4,测试准确率=0.49609375
# epoch=5,测试准确率=0.49609375
# epoch=6,测试准确率=0.49609375
# epoch=7,测试准确率=0.49609375
# epoch=8,测试准确率=0.49609375
# epoch=9,测试准确率=0.49609375
# epoch=10,测试准确率=0.49609375
# epoch=11,测试准确率=0.5
# epoch=12,测试准确率=0.5
# epoch=13,测试准确率=0.5
# epoch=14,测试准确率=0.5078125
# epoch=15,测试准确率=0.513671875
# epoch=16,测试准确率=0.50390625
# epoch=17,测试准确率=0.505859375
# epoch=18,测试准确率=0.501953125
# epoch=19,测试准确率=0.5
# epoch=20,测试准确率=0.498046875
# epoch=21,测试准确率=0.498046875
# epoch=22,测试准确率=0.509765625
# epoch=23,测试准确率=0.525390625
# epoch=24,测试准确率=0.541015625
# epoch=25,测试准确率=0.57421875
# epoch=26,测试准确率=0.658203125
# epoch=27,测试准确率=0.669921875
# ...
